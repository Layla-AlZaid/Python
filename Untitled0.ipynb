# %%
from google.colab import drive
drive.mount("/drive")
# Out:
# Mounted at /drive

# %%
# !pip install pyxlsb

# %%
import numpy as np
import pyxlsb
import pandas as pd # Changed dp to pd

# %%
# Corrected file path to access the file in Google Drive
file = pd.read_excel("/drive/MyDrive/Excel.xlsx")
# Ensure the filename and extension are correct (Excel.xlsx)

# %%
file
# Out:
#   Unnamed: 0  الرقم الوظيفي    رقم الهوية  المهنة      الراتب    البدلات
# 0      count      31.000000  3.100000e+01      31     5.00000    25.0000
# 1       mean      53.645161  2.143615e+09       0  1760.00000    80.0000
# 2        std      38.011006  5.786912e+08       0  1824.28068   312.2499
# 3        min       1.000000  1.047162e+09       0     0.00000     0.0000
# 4        25%      21.000000  2.168145e+09       0     0.00000     0.0000
# 5        50%      52.000000  2.460428e+09       0  1600.00000     0.0000
# 6        75%      86.500000  2.512325e+09       0  3200.00000     0.0000
# 7        max     115.000000  2.559156e+09       0  4000.00000  1500.0000

# %%
file.head(10)
# Out:
#   Unnamed: 0  الرقم الوظيفي    رقم الهوية  المهنة      الراتب    البدلات
# 0      count      31.000000  3.100000e+01      31     5.00000    25.0000
# 1       mean      53.645161  2.143615e+09       0  1760.00000    80.0000
# 2        std      38.011006  5.786912e+08       0  1824.28068   312.2499
# 3        min       1.000000  1.047162e+09       0     0.00000     0.0000
# 4        25%      21.000000  2.168145e+09       0     0.00000     0.0000
# 5        50%      52.000000  2.460428e+09       0  1600.00000     0.0000
# 6        75%      86.500000  2.512325e+09       0  3200.00000     0.0000
# 7        max     115.000000  2.559156e+09       0  4000.00000  1500.0000

# %%
file.describe()
# Out:
#        الرقم الوظيفي    رقم الهوية     المهنة       الراتب      البدلات
# count       8.000000  8.000000e+00   8.000000     8.000000     8.000000
# mean       49.769521  1.683690e+09   3.875000  1548.660085   239.656237
# std        36.490406  9.973985e+08  10.960155  1513.691822   520.308165
# min         1.000000  3.100000e+01   0.000000     0.000000     0.000000
# 25%        28.500000  9.300446e+08   0.000000     3.750000     0.000000
# 50%        45.005503  2.155880e+09   0.000000  1680.000000    12.500000
# 75%        61.858871  2.473402e+09   0.000000  2168.210510   138.062475
# max       115.000000  2.559156e+09  31.000000  4000.000000  1500.000000

# %%
file.isna().sum()
# Out:
# Unnamed: 0       0
# الرقم الوظيفي    0
# رقم الهوية       0
# المهنة           0
# الراتب           0
# البدلات          0
# dtype: int64

# %%
x=file['الجنسية'].count()
file.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'الجنسية'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-252489ab71ba> in <cell line: 1>()
# ----> 1 x=file['الجنسية'].count()
#       2 file.isna().sum()
#
# ...

# %%
file.fillna(0,inplace=True)
file.isna().sum()
# Out:
# Unnamed: 0       0
# الرقم الوظيفي    0
# رقم الهوية       0
# المهنة           0
# الراتب           0
# البدلات          0
# dtype: int64

# %%
for x in file.index:
  if file.loc[x,'البدلات']==3000:
    y=file.loc[x,'البدلات']-200
    file.loc[x,'البدلات']=y

# %%
file.head(30)
# Out:
#   Unnamed: 0  الرقم الوظيفي    رقم الهوية  المهنة      الراتب    البدلات
# 0      count      31.000000  3.100000e+01      31     5.00000    25.0000
# 1       mean      53.645161  2.143615e+09       0  1760.00000    80.0000
# 2        std      38.011006  5.786912e+08       0  1824.28068   312.2499
# 3        min       1.000000  1.047162e+09       0     0.00000     0.0000
# 4        25%      21.000000  2.168145e+09       0     0.00000     0.0000
# 5        50%      52.000000  2.460428e+09       0  1600.00000     0.0000
# 6        75%      86.500000  2.512325e+09       0  3200.00000     0.0000
# 7        max     115.000000  2.559156e+09       0  4000.00000  1500.0000

# %%
for x in file.index:
  if file.loc[x,'الراتب']==1000:
   file.drop(x,inplace=True)

# %%
file
# Out:
#   Unnamed: 0  الرقم الوظيفي    رقم الهوية  المهنة      الراتب    البدلات
# 0      count      31.000000  3.100000e+01      31     5.00000    25.0000
# 1       mean      53.645161  2.143615e+09       0  1760.00000    80.0000
# 2        std      38.011006  5.786912e+08       0  1824.28068   312.2499
# 3        min       1.000000  1.047162e+09       0     0.00000     0.0000
# 4        25%      21.000000  2.168145e+09       0     0.00000     0.0000
# 5        50%      52.000000  2.460428e+09       0  1600.00000     0.0000
# 6        75%      86.500000  2.512325e+09       0  3200.00000     0.0000
# 7        max     115.000000  2.559156e+09       0  4000.00000  1500.0000

# %%
file.drop_duplicates(inplace=True)
del file['رقم الموظف في مدد ']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'رقم الموظف في مدد '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-61032c44dce9> in <cell line: 2>()
#       1 file.drop_duplicates(inplace=True)
# ...

# %%
file
# Out:
#   Unnamed: 0  الرقم الوظيفي    رقم الهوية  المهنة      الراتب    البدلات
# 0      count      31.000000  3.100000e+01      31     5.00000    25.0000
# 1       mean      53.645161  2.143615e+09       0  1760.00000    80.0000
# 2        std      38.011006  5.786912e+08       0  1824.28068   312.2499
# 3        min       1.000000  1.047162e+09       0     0.00000     0.0000
# 4        25%      21.000000  2.168145e+09       0     0.00000     0.0000
# 5        50%      52.000000  2.460428e+09       0  1600.00000     0.0000
# 6        75%      86.500000  2.512325e+09       0  3200.00000     0.0000
# 7        max     115.000000  2.559156e+09       0  4000.00000  1500.0000

# %%
file.drop_duplicates(inplace=True)
del file['الايبان']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'الايبان'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-c1e92a11c301> in <cell line: 2>()
#       1 file.drop_duplicates(inplace=True)
# ----> 2 del file['الايبان']
#
# ...

# %%
file
# Out:
#   Unnamed: 0  الرقم الوظيفي    رقم الهوية  المهنة      الراتب    البدلات
# 0      count      31.000000  3.100000e+01      31     5.00000    25.0000
# 1       mean      53.645161  2.143615e+09       0  1760.00000    80.0000
# 2        std      38.011006  5.786912e+08       0  1824.28068   312.2499
# 3        min       1.000000  1.047162e+09       0     0.00000     0.0000
# 4        25%      21.000000  2.168145e+09       0     0.00000     0.0000
# 5        50%      52.000000  2.460428e+09       0  1600.00000     0.0000
# 6        75%      86.500000  2.512325e+09       0  3200.00000     0.0000
# 7        max     115.000000  2.559156e+09       0  4000.00000  1500.0000

# %%
# Convert the 'الراتب' column to numeric type before filtering
file['الراتب'] = pd.to_numeric(file['الراتب'], errors='coerce')

# Now you can filter the DataFrame:
df = file[(file['الراتب'] <= 4000)]

# %%
df
# Out:
#   Unnamed: 0  الرقم الوظيفي    رقم الهوية  المهنة      الراتب    البدلات
# 0      count      31.000000  3.100000e+01      31     5.00000    25.0000
# 1       mean      53.645161  2.143615e+09       0  1760.00000    80.0000
# 2        std      38.011006  5.786912e+08       0  1824.28068   312.2499
# 3        min       1.000000  1.047162e+09       0     0.00000     0.0000
# 4        25%      21.000000  2.168145e+09       0     0.00000     0.0000
# 5        50%      52.000000  2.460428e+09       0  1600.00000     0.0000
# 6        75%      86.500000  2.512325e+09       0  3200.00000     0.0000
# 7        max     115.000000  2.559156e+09       0  4000.00000  1500.0000

# %%
# Convert the 'الراتب' column to numeric type before filtering
file['البدلات'] = pd.to_numeric(file['البدلات'], errors='coerce')

# Now you can filter the DataFrame:
df = file[(file['البدلات'] <= 2000)]

# %%
def filee(marks):
   return(marks+5)

# %%
file['البدلات'].apply(filee)
# Out:
# 0      30.0000
# 1      85.0000
# 2     317.2499
# 3       5.0000
# 4       5.0000
# 5       5.0000
# 6       5.0000
# 7    1505.0000
# Name: البدلات, dtype: float64

# %%
file.sort_values('الراتب', ascending=False)
# Out:
#   Unnamed: 0  الرقم الوظيفي    رقم الهوية  المهنة      الراتب    البدلات
# 7        max     115.000000  2.559156e+09       0  4000.00000  1500.0000
# 6        75%      86.500000  2.512325e+09       0  3200.00000     0.0000
# 2        std      38.011006  5.786912e+08       0  1824.28068   312.2499
# 1       mean      53.645161  2.143615e+09       0  1760.00000    80.0000
# 5        50%      52.000000  2.460428e+09       0  1600.00000     0.0000
# 0      count      31.000000  3.100000e+01      31     5.00000    25.0000
# 3        min       1.000000  1.047162e+09       0     0.00000     0.0000
# 4        25%      21.000000  2.168145e+09       0     0.00000     0.0000

# %%
file.describe()
# Out:
#        الرقم الوظيفي    رقم الهوية     المهنة       الراتب      البدلات
# count       8.000000  8.000000e+00   8.000000     8.000000     8.000000
# mean       49.769521  1.683690e+09   3.875000  1548.660085   239.656237
# std        36.490406  9.973985e+08  10.960155  1513.691822   520.308165
# min         1.000000  3.100000e+01   0.000000     0.000000     0.000000
# 25%        28.500000  9.300446e+08   0.000000     3.750000     0.000000
# 50%        45.005503  2.155880e+09   0.000000  1680.000000    12.500000
# 75%        61.858871  2.473402e+09   0.000000  2168.210510   138.062475
# max       115.000000  2.559156e+09  31.000000  4000.000000  1500.000000

# %%
data=file.describe()

# %%
file.to_excel('/drive/MyDrive/file.xlsx')

# %%
import numpy as np
import pyxlsb
import pandas as pd # Changed dp to pd

# %%
l=[12,68,4]
a=np.array([2,3,5])
m={'a':[1],'b':[6],'c':[3]}
y=pd.Series()

# %%
u=pd.Series([])
p=pd.Series(l)
o=pd.Series(a)
i=pd.Series(m)
print(u)
print(p)
print(o)
print(i)
# Out:
# Series([], dtype: object)
# 0    12
# 1    68
# 2     4
# dtype: int64
# 0    2
# 1    3
# 2    5
# dtype: int64
# a    [1]
# b    [6]
# c    [3]
# dtype: object

# %%
import numpy as np
import pyxlsb
import pandas as pd # Changed dp to pd

l=[12,68,4]
# Define 'a' before using it
a = np.array([2, 3, 5])
m={'a':1,'b':6,'c':3}
y=pd.Series([])

u=pd.Series(y)
p=pd.Series(l)
o=pd.Series(a)
i=pd.Series(m)
print(y)
print(p)
print(o)
print(i)
# Out:
# Series([], dtype: object)
# 0    12
# 1    68
# 2     4
# dtype: int64
# 0    2
# 1    3
# 2    5
# dtype: int64
# a    1
# b    6
# c    3
# dtype: int64

# %%
m={'name':['ali','sara','noor'], 'age':[20,25,24]}

# %%
pd.DataFrame(m)
# Out:
#    name  age
# 0   ali   20
# 1  sara   25
# 2  noor   24

# %%
y=pd.Series(['ali','sara','noor'])
y
# Out:
# 0     ali
# 1    sara
# 2    noor
# dtype: object

# %%
pd.Series_dtype(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-8f6813ee4f45> in <cell line: 1>()
# ----> 1 pd.Series_dtype(y)
#
# AttributeError: module 'pandas' has no attribute 'Series_dtype'

# %%
y.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
y.array
# Out:
# <NumpyExtensionArray>
# ['ali', 'sara', 'noor']
# Length: 3, dtype: object

# %%
y.size
# Out:
# 3

# %%
y.shape
# Out:
# (3,)

# %%
y.memory_usage(index=False)
# Out:
# 24

# %%
y.ndim
# Out:
# 1

# %%
y.nbytes
# Out:
# 24

# %%
y.empty
# Out:
# False

# %%
s1=pd.Series([6,3,9,8])
s2=pd.Series([7,4,9,5])

# %%
s1.add(s2)
# Out:
# 0    13
# 1     7
# 2    18
# 3    13
# dtype: int64

# %%
s1.subtract(s2)
# Out:
# 0    13
# 1     7
# 2    18
# 3    13
# dtype: int64

# %%
s1.multiply(s2)
# Out:
# 0    42
# 1    12
# 2    81
# 3    40
# dtype: int64

# %%
s1.divide(s2)
# Out:
# 0    0.857143
# 1    0.750000
# 2    1.000000
# 3    1.600000
# dtype: float64

# %%
s1.mod(s2)
# Out:
# 0    6
# 1    3
# 2    0
# 3    3
# dtype: int64

# %%
s1.pow(s2)
# Out:
# 0       279936
# 1           81
# 2    387420489
# 3        32768
# dtype: int64

# %%
s1.le(s2)
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# dtype: bool

# %%
s2.gt(s1)
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
s2.equals(s1)
# Out:
# False

# %%
file = pd.read_excel("/drive/MyDrive/heathy.xlsx")
# Ensure the filename and extension are correct (Excel.xlsx)

# %%
pd.DataFrame(file)
# Out:
#           Country Country_Code  Year  Fertility_Rate  \
# 0     Afghanistan          AFG  2012           5.830
# 1     Afghanistan          AFG  2013           5.696
# 2     Afghanistan          AFG  2014           5.560
# 3     Afghanistan          AFG  2015           5.405
# 4     Afghanistan          AFG  2016           5.262
# ...           ...          ...   ...             ...
# 1875     Zimbabwe          ZWE  2017           3.706
# 1876     Zimbabwe          ZWE  2018           3.659
# 1877     Zimbabwe          ZWE  2019           3.599
# 1878     Zimbabwe          ZWE  2020           3.545
# 1879     Zimbabwe          ZWE  2021           3.491
#
#       Urban_Population_Percent  Total_Population  Water_Access_Percent  \
# 0                       24.160          30466479             21.123996
# 1                       24.373          31541209             22.034470
# 2                       24.587          32716210             22.944301
# ...

# %%
file.tail(20)
# Out:
#        Country Country_Code  Year  Fertility_Rate  Urban_Population_Percent  \
# 1860    Zambia          ZMB  2012           5.146                    40.354
# 1861    Zambia          ZMB  2013           5.026                    40.865
# 1862    Zambia          ZMB  2014           4.899                    41.382
# 1863    Zambia          ZMB  2015           4.793                    41.907
# 1864    Zambia          ZMB  2016           4.707                    42.438
# 1865    Zambia          ZMB  2017           4.614                    42.976
# 1866    Zambia          ZMB  2018           4.536                    43.521
# 1867    Zambia          ZMB  2019           4.451                    44.072
# 1868    Zambia          ZMB  2020           4.379                    44.629
# 1869    Zambia          ZMB  2021           4.308                    45.192
# 1870  Zimbabwe          ZWE  2012           4.096                    32.834
# ...

# %%
file.describe()
# Out:
#               Year  Fertility_Rate  Urban_Population_Percent  \
# count  1880.000000     1844.000000               1880.000000
# mean   2016.500000        2.762999                 58.616514
# std       2.873046        1.345580                 23.170964
# min    2012.000000        0.808000                 11.194000
# 25%    2014.000000        1.670000                 40.069000
# 50%    2016.500000        2.311000                 58.884000
# 75%    2019.000000        3.645500                 77.633750
# max    2021.000000        7.400000                100.000000
#
#        Total_Population  Water_Access_Percent  Unemployment_Rate  \
# count      1.880000e+03           1225.000000         1740.00000
# mean       3.959636e+07             68.156944            7.68353
# std        1.452288e+08             30.828206            5.73873
# min        1.044400e+04              5.863130            0.10000
# 25%        2.061738e+06             44.033993            3.71550
# ...

# %%
file.shape
# Out:
# (1880, 29)

# %%
file.columns
# Out:
# Index(['Country', 'Country_Code', 'Year', 'Fertility_Rate',
#        'Urban_Population_Percent', 'Total_Population', 'Water_Access_Percent',
#        'Unemployment_Rate', 'Sanitary_Expense_Per_GDP', 'Life_Expectancy',
#        'Life_Expectancy_Female', 'Life_Expectancy_Male', 'Infant_Deaths',
#        'GDP_Per_Capita', 'Hospital_Beds_Per_1000', 'Female_Population',
#        'Male_Population', 'Alcohol_Consumption_Per_Capita',
#        'Immunization_Rate', 'Sanitary_Expense_Per_Capita',
#        'CO2_Exposure_Percent', 'Air_Pollution', 'Labour_Force_Total',
#        'Tuberculosis_Per_100000', 'Suicide_Rate_Percent',
#        'Obesity_Rate_Percent', 'Underweight_Rate_Percent',
#        'Overweight_Rate_Percent', 'Safe_Water_Access_Percent'],
#       dtype='object')

# %%
file[['Suicide_Rate_Percent','Labour_Force_Total']]
# Out:
#       Suicide_Rate_Percent  Labour_Force_Total
# 0                     3.68           7520865.0
# 1                     3.66           7881567.0
# 2                     3.60           8285362.0
# 3                     3.57           8630724.0
# 4                     3.61           8913938.0
# ...                    ...                 ...
# 1875                 15.02           5626689.0
# 1876                 14.00           5770751.0
# 1877                 14.12           5912685.0
# 1878                   NaN           6001349.0
# 1879                   NaN           6182422.0
#
# [1880 rows x 2 columns]

# %%
file[2:30:4]
# Out:
#         Country Country_Code  Year  Fertility_Rate  Urban_Population_Percent  \
# 2   Afghanistan          AFG  2014           5.560                    24.587
# 6   Afghanistan          AFG  2018           5.002                    25.495
# 10      Albania          ALB  2012           1.692                    54.330
# 14      Albania          ALB  2016           1.551                    58.421
# 18      Albania          ALB  2020           1.400                    62.112
# 22      Algeria          DZA  2014           3.004                    70.221
# 26      Algeria          DZA  2018           3.023                    72.629
#
#     Total_Population  Water_Access_Percent  Unemployment_Rate  \
# 2           32716210             22.944301              7.915
# 6           36686784             26.581315             11.206
# 10           2900401             66.380852             13.376
# 14           2876101             70.616508             15.418
# ...

# %%
file[20:100]
# Out:
#     Country Country_Code  Year  Fertility_Rate  Urban_Population_Percent  \
# 20  Algeria          DZA  2012           2.956                    68.915
# 21  Algeria          DZA  2013           2.957                    69.576
# 22  Algeria          DZA  2014           3.004                    70.221
# 23  Algeria          DZA  2015           3.041                    70.848
# 24  Algeria          DZA  2016           3.051                    71.459
# ..      ...          ...   ...             ...                       ...
# 95  Austria          AUT  2017           1.520                    58.094
# 96  Austria          AUT  2018           1.470                    58.297
# 97  Austria          AUT  2019           1.460                    58.515
# 98  Austria          AUT  2020           1.440                    58.748
# 99  Austria          AUT  2021           1.480                    58.995
#
#     Total_Population  Water_Access_Percent  Unemployment_Rate  \
# ...

# %%
file.loc[6]
# Out:
# Country                           Afghanistan
# Country_Code                              AFG
# Year                                     2018
# Fertility_Rate                          5.002
# Urban_Population_Percent               25.495
# Total_Population                     36686784
# Water_Access_Percent                26.581315
# Unemployment_Rate                      11.206
# Sanitary_Expense_Per_GDP            14.208419
# Life_Expectancy                        63.081
# Life_Expectancy_Female                 66.458
# Life_Expectancy_Male                   59.923
# Infant_Deaths                         66824.0
# GDP_Per_Capita                     492.090631
# Hospital_Beds_Per_1000                    0.4
# Female_Population                    18136922
# Male_Population                      18549862
# Alcohol_Consumption_Per_Capita          0.016
# Immunization_Rate                        72.0
# Sanitary_Expense_Per_Capita         71.334305
# ...

# %%
file[['Air_Pollution','Overweight_Rate_Percent']][7:30]
# Out:
#     Air_Pollution  Overweight_Rate_Percent
# 7       58.330872                    40.27
# 8       46.087094                    41.54
# 9             NaN                    42.81
# 10      20.962720                    53.49
# 11      19.407532                    53.90
# 12      19.367944                    54.31
# 13      19.121557                    54.73
# 14      17.602164                    55.16
# 15      18.555244                    55.59
# 16      19.046186                    56.01
# 17      15.704707                    56.43
# 18      15.707004                    56.85
# 19            NaN                    57.27
# 20      24.396816                    42.02
# 21      22.380264                    42.88
# 22      24.111123                    43.75
# 23      25.618866                    44.62
# 24      25.553153                    45.50
# 25      24.752146                    46.35
# 26      24.933590                    47.16
# 27      24.388609                    47.94
# ...

# %%
file.loc[file['Country'] == 'Austria']
# Out:
#     Country Country_Code  Year  Fertility_Rate  Urban_Population_Percent  \
# 90  Austria          AUT  2012            1.44                    57.147
# 91  Austria          AUT  2013            1.44                    57.336
# 92  Austria          AUT  2014            1.46                    57.526
# 93  Austria          AUT  2015            1.49                    57.715
# 94  Austria          AUT  2016            1.53                    57.905
# 95  Austria          AUT  2017            1.52                    58.094
# 96  Austria          AUT  2018            1.47                    58.297
# 97  Austria          AUT  2019            1.46                    58.515
# 98  Austria          AUT  2020            1.44                    58.748
# 99  Austria          AUT  2021            1.48                    58.995
#
#     Total_Population  Water_Access_Percent  Unemployment_Rate  \
# 90           8429991             98.774353              4.909
# ...

# %%
file.loc[file['Fertility_Rate'] > 1.44]
# Out:
#           Country Country_Code  Year  Fertility_Rate  \
# 0     Afghanistan          AFG  2012           5.830
# 1     Afghanistan          AFG  2013           5.696
# 2     Afghanistan          AFG  2014           5.560
# 3     Afghanistan          AFG  2015           5.405
# 4     Afghanistan          AFG  2016           5.262
# ...           ...          ...   ...             ...
# 1875     Zimbabwe          ZWE  2017           3.706
# 1876     Zimbabwe          ZWE  2018           3.659
# 1877     Zimbabwe          ZWE  2019           3.599
# 1878     Zimbabwe          ZWE  2020           3.545
# 1879     Zimbabwe          ZWE  2021           3.491
#
#       Urban_Population_Percent  Total_Population  Water_Access_Percent  \
# 0                       24.160          30466479             21.123996
# 1                       24.373          31541209             22.034470
# 2                       24.587          32716210             22.944301
# ...

# %%
file.sort_values(['Year'],ascending=False)
# Out:
#                     Country Country_Code  Year  Fertility_Rate  \
# 1879               Zimbabwe          ZWE  2021           3.491
# 1759                 Uganda          UGA  2021           4.585
# 969                 Liberia          LBR  2021           4.089
# 959                 Lesotho          LSO  2021           3.018
# 949                 Lebanon          LBN  2021           2.091
# ...                     ...          ...   ...             ...
# 1120                Moldova          MDA  2012           1.659
# 1110  Micronesia, Fed. Sts.          FSM  2012           3.130
# 1100                 Mexico          MEX  2012           2.294
# 1090              Mauritius          MUS  2012           1.540
# 940                 Lebanon          LBN  2012           2.169
#
#       Urban_Population_Percent  Total_Population  Water_Access_Percent  \
# 1879                    32.303          15993524             26.476995
# ...

# %%
file.sort_values(['Year'])
# Out:
#                Country Country_Code  Year  Fertility_Rate  \
# 0          Afghanistan          AFG  2012           5.830
# 220           Botswana          BWA  2012           2.981
# 660             Greece          GRC  2012           1.340
# 1480            Serbia          SRB  2012           1.450
# 1040          Maldives          MDV  2012           2.202
# ...                ...          ...   ...             ...
# 1099         Mauritius          MUS  2021           1.410
# 1089        Mauritania          MRT  2021           4.398
# 1079  Marshall Islands          MHL  2021           2.729
# 1159        Montenegro          MNE  2021           1.750
# 1879          Zimbabwe          ZWE  2021           3.491
#
#       Urban_Population_Percent  Total_Population  Water_Access_Percent  \
# 0                       24.160          30466479             21.123996
# 220                     64.768           2175425                   NaN
# ...
